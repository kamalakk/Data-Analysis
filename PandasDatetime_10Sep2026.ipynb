# %% [markdown]
# <a href="https://colab.research.google.com/github/kamalakk/Data-Analysis/blob/main/PandasDatetime_10Sep2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas Date time 10 Sep 2026

# %%
import pandas as pd
import datetime as dt

# %%
today = dt.date(2019,7,12)
#today.year
today.month
#today.day
# Out:
# 7

# %%
datewithtimestamp = dt.datetime(2020,1,23,23,54,34)
print(datewithtimestamp)
datewithtimestamp.hour
datewithtimestamp.minute
datewithtimestamp.second
#datewithtimestamp.microsecond
# Out:
# 2020-01-23 23:54:34
# 34

# %%
#pd.Timestamp("2022-2-15")
#pd.Timestamp("2022/2/15")
#pd.Timestamp("2022, 2, 15")
pd.Timestamp("2022-2-15 15:12:13")
# pd.Timestamp("2022-2-15 15:12:13 PM")
# Out:
# Timestamp('2022-02-15 15:12:13')

# %%
from numpy import dtype
dates = ["2022-2-13", "2022-3-14", "2022-4-16"]
type(dates)
pd.DatetimeIndex(dates)
# Out:
# DatetimeIndex(['2022-02-13', '2022-03-14', '2022-04-16'], dtype='datetime64[ns]', freq=None)

# %%
dates =  [dt.date(2022, 2, 13), dt.date(2022,3,4), dt.date(2022,5,16)]
type(dates)

dateindex= pd.DatetimeIndex(dates)
dateindex
# Out:
# DatetimeIndex(['2022-02-13', '2022-03-04', '2022-05-16'], dtype='datetime64[ns]', freq=None)

# %%
values = [10,13,20]
pd.Series(data=values, index=dateindex)
# Out:
# 2022-02-13    10
# 2022-03-04    13
# 2022-05-16    20
# dtype: int64

# %% [markdown]
# pd.to_datetime

# %%
pd.to_datetime('2022-12-03')
# Out:
# Timestamp('2022-12-03 00:00:00')

# %%
pd.to_datetime(dt.date(2022,12,3))
# Out:
# Timestamp('2022-12-03 00:00:00')

# %%
pd.to_datetime(dt.datetime(2022,12,3,14,34,20))
# Out:
# Timestamp('2022-12-03 14:34:20')

# %%
dates=['2022/12/13', '2022/1/23', '2022/4/16']
pd.to_datetime(dates)
# Out:
# DatetimeIndex(['2022-12-13', '2022-01-23', '2022-04-16'], dtype='datetime64[ns]', freq=None)

# %%
dates = pd.Series(['December 22nd, 2019', "2019, 12, 22", "This is Date", 'Dec 23rd, 2019', '24th Dec, 2019'])
dates
# Out:
# 0    December 22nd, 2019
# 1           2019, 12, 22
# 2           This is Date
# 3         Dec 23rd, 2019
# 4         24th Dec, 2019
# dtype: object

# %%
dates = pd.to_datetime(dates, errors='coerce')
dates
# Out:
# 0   2019-12-22
# 1          NaT
# 2          NaT
# 3          NaT
# 4          NaT
# dtype: datetime64[ns]

# %%
unixtime= [float('12345689'),float('45678901'),float('8904567234')]
pd.to_datetime(unixtime, unit='s')
# Out:
# DatetimeIndex(['1970-05-23 21:21:29', '1971-06-13 16:35:01',
#                '2252-03-05 02:53:54'],
#               dtype='datetime64[ns]', freq=None)

# %%
pd.date_range(start='2016-01-01', end='2016-01-10', freq='D')
# Out:
# DatetimeIndex(['2016-01-01', '2016-01-02', '2016-01-03', '2016-01-04',
#                '2016-01-05', '2016-01-06', '2016-01-07', '2016-01-08',
#                '2016-01-09', '2016-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
from pandas_datareader import data

# %%
company = "MSFT"
start = "2019-01-01"
end = "2019-12-22"

# %% [markdown]
# Time Delta

# %%
timeA = pd.Timestamp('2019-12-2 16:13:12')
timeB = pd.Timestamp('2019-6-6  15:12:1')
timeA - timeB
# Out:
# Timedelta('179 days 01:01:11')

# %%
pd.Timedelta( weeks = 10, days = 20 , minutes=20)
# Out:
# Timedelta('90 days 00:20:00')

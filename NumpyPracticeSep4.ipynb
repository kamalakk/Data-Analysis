# %% [markdown]
# <a href="https://colab.research.google.com/github/kamalakk/Data-Analysis/blob/main/NumpyPracticeSep4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Numpy Practice 4-Sep-2026

# %%
import numpy as np

# %%
array1=np.array('A')
print(array1)
print(array1.ndim)
print(np.__version__)
# Out:
# A
# 0
# 2.1.3

# %%
mylist = [1,2,3,4]
multylist = mylist * 2
print(multylist)
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4]

# %%
nparray= np.array([1,2,3,4])
nparray= nparray * 2
print(nparray)
print(type(nparray))
# Out:
# [2 4 6 8]
# <class 'numpy.ndarray'>

# %%
tdarray = np.array([
                   ['a','b','c'],
                   ['d','e','f'],
                   ['g','h','i']])
print(tdarray.ndim)
print(tdarray.shape)
print(tdarray.size)
# Out:
# 2
# (3, 3)
# 9

# %% [markdown]
# <a href="https://colab.research.google.com/github/kamalakk/Data-Analysis/blob/main/PandasAggregateFn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aggragate function

# %%
import pandas as pd
#df = pd.read_csv('/content/Flavors.csv', index_col='Flavor')
df = pd.read_csv('/content/Flavors.csv')

df
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %%
#df.mean(numeric_only=True)
#df.sum(numeric_only=True)
#df.min(numeric_only=True)
#df.max(numeric_only=True)
df.count()
# Out:
# Flavor            9
# Base Flavor       9
# Liked             9
# Flavor Rating     9
# Texture Rating    9
# Total Rating      9
# dtype: int64

# %%
#single column Flavor Rating	Texture Rating	Total Rating
df['Flavor Rating'].mean()
#df['Flavor Rating'].sum()
#df['Flavor Rating'].min()
#df['Flavor Rating'].max()
#df['Flavor Rating'].count()
# Out:
# np.float64(6.6000000000000005)

# %%
groupvar = df.groupby('Base Flavor')
#groupvar.mean(numeric_only=True)
#groupvar['Total Rating'].mean()
groupvar["Total Rating"].sum()
# Out:
# Base Flavor
# Chocolate    47.1
# Vanilla      68.1
# Name: Total Rating, dtype: float64

# %% [markdown]
# Selection in Pandas

# %%
df
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %%
df[["Flavor Rating",	"Texture Rating",	"Total Rating"]]
# Out:
#    Flavor Rating  Texture Rating  Total Rating
# 0           10.0             8.0          18.0
# 1            8.8             7.6          16.6
# 2            4.7             5.0           9.7
# 3            6.9             6.5          13.4
# 4            8.2             7.0          15.2
# 5            2.3             3.4           5.7
# 6            6.5             6.0          12.5
# 7            3.8             5.0           8.8
# 8            8.2             7.1          15.3

# %%
# loc property
df.loc[1]
# Out:
# Flavor            Chocolate
# Base Flavor       Chocolate
# Liked                   Yes
# Flavor Rating           8.8
# Texture Rating          7.6
# Total Rating           16.6
# Name: 1, dtype: object

# %%
df
# Out:
#                        Base Flavor Liked  Flavor Rating  Texture Rating  \
# Flavor
# Mint Chocolate Chip        Vanilla   Yes           10.0             8.0
# Chocolate                Chocolate   Yes            8.8             7.6
# Vanilla                    Vanilla    No            4.7             5.0
# Cookie Dough               Vanilla   Yes            6.9             6.5
# Rocky Road               Chocolate   Yes            8.2             7.0
# Pistachio                  Vanilla    No            2.3             3.4
# Cake Batter                Vanilla   Yes            6.5             6.0
# Neapolitan                 Vanilla    No            3.8             5.0
# Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#                         Total Rating
# Flavor
# Mint Chocolate Chip             18.0
# Chocolate                       16.6
# Vanilla                          9.7
# Cookie Dough                    13.4
# Rocky Road                      15.2
# ...

# %%
df.loc['Vanilla']
# Out:
# Base Flavor       Vanilla
# Liked                  No
# Flavor Rating         4.7
# Texture Rating        5.0
# Total Rating          9.7
# Name: Vanilla, dtype: object

# %%
#df.loc['Cake Batter',['Flavor Rating','Texture Rating']]
df.loc['Cookie Dough':'Cake Batter',['Flavor Rating','Texture Rating']]
# Out:
#               Flavor Rating  Texture Rating
# Flavor
# Cookie Dough            6.9             6.5
# Rocky Road              8.2             7.0
# Pistachio               2.3             3.4
# Cake Batter             6.5             6.0

# %% [markdown]
# Integer location

# %%
#df.iloc[0:4]
df.iloc[0:4:2,0:3]
# Out:
#                     Base Flavor Liked  Flavor Rating
# Flavor
# Mint Chocolate Chip     Vanilla   Yes           10.0
# Vanilla                 Vanilla    No            4.7

# %%
inputvar = input("Enter number ")

try:
     df.loc[inputvar]
except KeyError:
   print ("data not found")
#finally:
   # print("un expected finally block")
# Out:
# Enter number 4
# data not found

# %% [markdown]
# Filtering

# %%
df
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %%
df[df['Flavor Rating'] >= 4]
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 6          12.5
# 8          15.3

# %%
#df[df['Flavor'] == 'Cookie Dough']
df[(df['Flavor'] == 'Cookie Dough') | (df['Flavor'] == 'Rocky Road')]
# Out:
#          Flavor Base Flavor Liked  Flavor Rating  Texture Rating  Total Rating
# 3  Cookie Dough     Vanilla   Yes            6.9             6.5          13.4
# 4    Rocky Road   Chocolate   Yes            8.2             7.0          15.2
